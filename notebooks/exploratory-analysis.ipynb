# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import seaborn as sns

from src.data.load_data import load_sample_data, get_x_y
from src.plot.image import plot_one_letter, plot_grid_of_letters
from src.utils.constants import nb_classes
from src.utils.misc import init_notebook

# %%
init_notebook()

# %%
df = load_sample_data()

# %%
print(f"{df.shape = }")
# Out:
# df.shape = (3000, 785)

# %%
X, y = get_x_y(df)

# %%
print(f"{X.shape =}\n{y.shape =}")
# Out:
# X.shape =(3000, 784)
# y.shape =(3000,)

# %%
sns.histplot(df[0], bins=nb_classes)
# Out:
# <Axes: xlabel='0', ylabel='Count'>

# %%
for i in range(3):
    plot_one_letter(X, i)

# %%
title = "Some of the first letters in the dataset"
plot_grid_of_letters(X, title=title, nb_cols=10, figsize=(10, 4))
